# %% [markdown]
# ## Chapter 3: Visualizing Data

# %% [markdown]
# We visualize data to better _explore_ and _communicate_ what can be found in the data.
#
# The first tool to be used is the `matplotlib` library.
#
# `matplotlib` is **good for: bar charts, line charts, scatterplots**.

# %%
from matplotlib import pyplot as plt

% matplotlib inline

# %% [markdown]
# Let's make a simple plot with it.

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.2, 1075.9, 2863.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of #$")
plt.show()

# %% [markdown]
# ### Bar Charts
#
# Show how a quantity varies among discrete items in a set.

# %%
movies = ['Annie Hall', 'Ben Hur', 'Casablanca', 'Ghandi', 'West Side Story']
num_oscars = [5, 11, 3, 8, 10]

xs = [i + 0.5 for i, _ in enumerate(movies)]
# the book screwed this up too; moved these by 0.1 rather than 0.5. I fixed it.

plt.bar(xs, num_oscars)

plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")

plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

plt.show()

# %% [markdown]
# #### Histogram for _value distribution_:
#
# Histograms are for "bucketed numeric values"; shows how values are distributed. e.g. What were the grades like on that last test?

# %%
import random
from collections import Counter


grades = []
for i in range(30):
    grades.append(random.randint(0,100))  # making up some fake grades.

decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x for x in histogram.keys()],  # this is the value for each bar
        histogram.values(),  # the height of each bar (no alteraction; each has correct height already)
        8)  # bar width of 8; bucket has a width of 10 so this leaves a margin btwn them.

plt.axis([-5, 105, 0, 7]) # x-axis from -5 to 105; y-ax from 0-5

plt.xticks([10 * i for i in range(11)])  # x-axis labels by 10s
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %% [markdown]
# ### Line Charts
#
# To show _trends_

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label='variance')  # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2')  # red dot-dash line
plt.plot(xs, total_error, 'b:', label='total error')  # blue dotted line

# and now for a legend
plt.legend(loc=9)  # loc=9 means 'centered'
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ### Scatterplots
#
# Visualizing rltnshp between two paired sets of data.
#
# For example: # of friends a user has and amount of time they spend on your site.

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                 xy=(friend_count, minute_count),  # puts the label with its point
                 xytext=(5, -5),  # with a slight offset
                 textcoords='offset points',
                )
    
plt.title('Daily Minutes vs Number of Friends')
plt.xlabel('# of friends')
plt.ylabel('daily minutes spent on the site')

# %% [markdown]
# Also look at:
# * [seaborn](https://seaborn.pydata.org/) – "Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics."
# * d3.js – js library for producing interactive visualizations.
# * [bokeh](http://bokeh.pydata.org/en/latest/) – "Bokeh is a Python interactive visualization library that targets modern web browsers for presentation."
# * ggplot – Py port of an R library for creating charts & graphics.
